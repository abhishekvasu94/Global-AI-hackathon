# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

f = pd.read_csv('fake.csv')
f.head(2)
# f[f.spam_score>0].count()
# a = f.spam_score.unique()
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
#
#                                                 text language  \
# 0  Print They should pay all the back all the mon...  english
# 1  Why Did Attorney General Loretta Lynch Plead T...  english
#
#                          crawled             site_url country  domain_rank  \
# 0  2016-10-27T01:49:27.168+03:00  100percentfedup.com      US      25689.0
# 1  2016-10-29T08:47:11.259+03:00  100percentfedup.com      US      25689.0
#
#                                         thread_title  spam_score  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...         0.0
# 1  Re: Why Did Attorney General Loretta Lynch Ple...         0.0
#
#                                         main_img_url  replies_count  \
# 0  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 1  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
#
#    participants_count  likes  comments  shares  type
# 0                   1      0         0       0  bias
# 1                   1      0         0       0  bias

# %%
g = pd.read_csv('facebook-fact-check.csv')
g.head(2)
a = g.Rating.unique()
print a
for i in a:
    print g[g.Rating == i].count()
# Out:
# ['no factual content' 'mostly true' 'mixture of true and false'
#  'mostly false']
# account_id        264
# post_id           264
# Category          264
# Page              264
# Post URL          264
# Date Published    264
# Post Type         264
# Rating            264
# Debate             40
# share_count       235
# reaction_count    264
# comment_count     264
# dtype: int64
# account_id        1669
# post_id           1669
# Category          1669
# Page              1669
# Post URL          1669
# Date Published    1669
# Post Type         1669
# Rating            1669
# Debate             236
# share_count       1633
# reaction_count    1667
# comment_count     1667
# dtype: int64
# account_id        245
# post_id           245
# Category          245
# Page              245
# Post URL          245
# Date Published    245
# Post Type         245
# Rating            245
# Debate             15
# share_count       241
# reaction_count    245
# comment_count     245
# dtype: int64
# account_id        104
# post_id           104
# Category          104
# Page              104
# Post URL          104
# Date Published    104
# Post Type         104
# Rating            104
# Debate              7
# share_count       103
# reaction_count    104
# comment_count     104
# dtype: int64

# %%
f['class_type'] = 0
f['total_count'] = 0
for i in range(len(f)):
    if f.ix[i, 'spam_score'] < 0.2:
        f.ix[i,'class_type'] = "Real"
        
    elif f.ix[i,'spam_score'] > 0.2 and f.ix[i,'spam_score'] < 0.8:
        f.ix[i,'class_type'] = "Ambiguous"
        
    else:
        f.ix[i,'class_type'] = "Fake"
        
    f.ix[i,'total_count'] = f.ix[i, 'likes'] + f.ix[i, 'comments'] + f.ix[i, 'shares'] + f.ix[i, 'participants_count']
    
# f = f.drop('class', 1)
f.head()
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
#                                                 text language  \
# 0  Print They should pay all the back all the mon...  english
# 1  Why Did Attorney General Loretta Lynch Plead T...  english
# 2  Red State : \nFox News Sunday reported this mo...  english
# 3  Email Kayla Mueller was a prisoner and torture...  english
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  english
#
#                          crawled             site_url country     ...      \
# 0  2016-10-27T01:49:27.168+03:00  100percentfedup.com      US     ...
# 1  2016-10-29T08:47:11.259+03:00  100percentfedup.com      US     ...
# 2  2016-10-31T01:41:49.479+02:00  100percentfedup.com      US     ...
# 3  2016-11-01T15:46:26.304+02:00  100percentfedup.com      US     ...
# 4  2016-11-01T23:59:42.266+02:00  100percentfedup.com      US     ...
#
#    spam_score                                       main_img_url  \
# 0       0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 1       0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 2       0.000  http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# 3       0.068  http://100percentfedup.com/wp-content/uploads/...
# 4       0.865  http://100percentfedup.com/wp-content/uploads/...
#
#    replies_count participants_count  likes  comments  shares  type  \
# 0              0                  1      0         0       0  bias
# 1              0                  1      0         0       0  bias
# 2              0                  1      0         0       0  bias
# 3              0                  0      0         0       0  bias
# 4              0                  0      0         0       0  bias
#
#    class_type total_count
# 0        Real           1
# 1        Real           1
# 2        Real           1
# 3        Real           0
# 4        Fake           0
#
# [5 rows x 22 columns]

# %%
from clarifai.rest import ClarifaiApp
app = ClarifaiApp("YSiXrmkG3eH5YX-T0_IgOP2EiQCjUSSU3-Zi8-Ud", "7ZMENkzvW96jYqAw1cskml2tCYsnxMXWjcGsxTso")
a = app.tag_urls([f.main_img_url[0]])
# len(a['outputs'])
a
# print f.title[0]
# print f.text[0]
# Out:
# Hey! Clarifai Python Client v2.0.28 upgrade available.
# {u'outputs': [{u'created_at': u'2017-06-25T01:20:50.558719681Z',
#    u'data': {u'concepts': [{u'app_id': u'main',
#       u'id': u'ai_TJ9wFfK5',
#       u'name': u'portrait',
#       u'value': 0.99106073},
#      {u'app_id': u'main',
#       u'id': u'ai_l8TKp2h5',
#       u'name': u'people',
#       u'value': 0.98237133},
#      {u'app_id': u'main',
#       u'id': u'ai_dxSG2s86',
#       u'name': u'man',
#       u'value': 0.97912073},
#      {u'app_id': u'main',
#       u'id': u'ai_VPmHr5bm',
#       u'name': u'adult',
#       u'value': 0.9668279},
#      {u'app_id': u'main',
#       u'id': u'ai_SVshtN54',
#       u'name': u'one',
#       u'value': 0.9099671},
#      {u'app_id': u'main',
#       u'id': u'ai_dngMN46t',
#       u'name': u'fashion',
#       u'value': 0.8998294},
#      {u'app_id': u'main',
#       u'id': u'ai_GxSDhQ34',
#       u'name': u'facial expression',
#       u'value': 0.8828187},
#      {u'app_id': u'main',
#       u'id': u'ai_86sS08Pw',
#       u'name': u'wear',
#       u'value': 0.8773942},
#      {u'app_id': u'main',
#       u'id': u'ai_BpnQsTtg',
#       u'name': u'young',
#       u'value': 0.874584},
#      {u'app_id': u'main',
#       u'id': u'ai_fNR8CQHt',
#       u'name': u'fine-looking',
#       u'value': 0.8605474},
#      {u'app_id': u'main',
#       u'id': u'ai_vfV1Zf9w',
#       u'name': u'horizontal',
#       u'value': 0.8590517},
#      {u'app_id': u'main',
#       u'id': u'ai_8jtPl3Xj',
#       u'name': u'face',
#       u'value': 0.85898244},
#      {u'app_id': u'main',
#       u'id': u'ai_z2rl5nCM',
#       u'name': u'scarf',
#       u'value': 0.8549975},
#      {u'app_id': u'main',
#       u'id': u'ai_6lhccv44',
#       u'name': u'business',
#       u'value': 0.8464449},
#      {u'app_id': u'main',
#       u'id': u'ai_10q5fStp',
#       u'name': u'individuality',
#       u'value': 0.8459898},
#      {u'app_id': u'main',
#       u'id': u'ai_Lq00FggW',
#       u'name': u'desktop',
#       u'value': 0.83960307},
#      {u'app_id': u'main',
#       u'id': u'ai_58mskmJ1',
#       u'name': u'beard',
#       u'value': 0.82258284},
#      {u'app_id': u'main',
#       u'id': u'ai_9fQBzNBM',
#       u'name': u'looking',
#       u'value': 0.8170294},
#      {u'app_id': u'main',
#       u'id': u'ai_mvRRZ5Mq',
#       u'name': u'happiness',
#       u'value': 0.81202483},
#      {u'app_id': u'main',
#       u'id': u'ai_QGHBfsBT',
#       u'name': u'funny',
#       u'value': 0.8056847}]},
#    u'id': u'e57830dc8fa04cb79d3e5045234da806',
#    u'input': {u'data': {u'image': {u'url': u'http://bb4sp.com/wp-content/uploads/2016/10/Fullscreen-capture-10262016-83501-AM.bmp.jpg'}},
#     u'id': u'ae532acf4e5b4141b28ee20a4d22bffc'},
#    u'model': {u'app_id': u'main',
#     u'created_at': u'2016-03-09T17:11:39.608845Z',
#     u'id': u'aaa03c23b3724a16a56b629203edc62c',
#     u'model_version': {u'created_at': u'2016-07-13T01:19:12.147644Z',
#      u'id': u'aa9ca48295b37401f8af92ad1af0d91d',
#      u'status': {u'code': 21100,
#       u'description': u'Model trained successfully'}},
#     u'name': u'general-v1.3',
#     u'output_info': {u'message': u'Show output_info with: GET /models/{model_id}/output_info',
#      u'type': u'concept',
#      u'type_ext': u'concept'}},
#    u'status': {u'code': 10000, u'description': u'Ok'}}],
#  u'status': {u'code': 10000, u'description': u'Ok'}}

# %%
f.head()
y = pd.DataFrame()
y['output'] = f['class_type']
f = f.drop('class_type', 1)
f.head()
y['output_label'] = 0
for i in range(len(y)):
    if y.ix[i,'output'] == "Fake":
        y.ix[i,'output_label'] = 1
    elif y.ix[i,'output'] == "Ambiguous":
        y.ix[i,'output_label'] = 2
    else:
        y.ix[i,'output_label'] = 0
        
y.head()
# Out:
#   output  output_label
# 0   Real             0
# 1   Real             0
# 2   Real             0
# 3   Real             0
# 4   Fake             1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(f, y, test_size=0.2, random_state=42, stratify = y
                                                   )
print len(X_train)
print len(X_test)
print len(y_train)
print len(y_test)
# Out:
# 10399
# 2600
# 10399
# 2600

# %%
X_train.head()
# Out:
#                                            uuid  ord_in_thread  \
# 11400  aaf710db25ffa0c21ff92b7cff052098fa5307ed              0
# 9562   42ed84d36e018dd7012ec7c0d5be3772f15ac0c8              0
# 5243   42abbec003b0d993a6554362925b43b1cab05ccb              0
# 3777   ef1be063e8754ac155f3950f554510d757063d6a              0
# 3372   88df1b9d21daa1192270d34842bea3174ca09c7d              0
#
#                   author                      published  \
# 11400           Brett T.  2016-10-27T02:15:17.517+03:00
# 9562              Editor  2016-10-28T03:32:10.905+03:00
# 5243                 IWB  2016-10-27T17:13:41.770+03:00
# 3777   Lloyd Billingsley  2016-11-04T11:05:00.000+02:00
# 3372     Dr. Stoyan Sarg  2016-11-01T05:47:47.225+02:00
#
#                                                    title  \
# 11400  Who rode it best? Jesse Jackson mounts up to f...
# 9562   Scientists find 19 pieces of NON-HUMAN DNA in ...
# 5243   What Happens If Trump LOSES The Election? What...
# 3777                                  POTUS FLOTUS Pocus
# 3372         Are We on the Eve of Total Life Extinction?
#
#                                                     text language  \
# 11400  Who rode it best? Jesse Jackson mounts up to f...  english
# 9562   According to a new study, eight percent of our...  english
# 5243   What Happens If Trump LOSES The Election? What...  english
# 3777   The president and Hillary Clinton share a “stu...  english
# 3372   A 23 kiloton tower shot called BADGER, fired o...  english
#
#                              crawled                  site_url country  \
# 11400  2016-10-27T02:15:17.517+03:00               twitchy.com      US
# 9562   2016-10-28T03:32:10.905+03:00     theeventchronicle.com      US
# 5243   2016-10-27T17:13:41.770+03:00   investmentwatchblog.com      US
# 3777   2016-11-04T12:29:09.876+02:00          frontpagemag.com      US
# 3372   2016-11-01T05:47:47.225+02:00  foreignpolicyjournal.com      US
#
#           ...                                           thread_title  \
# 11400     ...      Who rode it best? Jesse Jackson mounts up to f...
# 9562      ...      Scientists find 19 pieces of NON-HUMAN DNA in ...
# 5243      ...      What Happens If Trump LOSES The Election? What...
# 3777      ...                                     POTUS FLOTUS Pocus
# 3372      ...            Are We on the Eve of Total Life Extinction?
#
#       spam_score                                       main_img_url  \
# 11400        0.0  http://twitchy.com/wp-content/uploads/2016/10/...
# 9562         0.0                                                NaN
# 5243         0.0                                                NaN
# 3777         0.0  http://www.frontpagemag.com/sites/default/file...
# 3372         0.0                                                NaN
#
#       replies_count  participants_count  likes  comments  shares  type  \
# 11400             0                   1      0         0       0    bs
# 9562              0                   1      0         0       0    bs
# 5243              0                   1      0         0       0    bs
# 3777              0                   1      0         0       0  hate
# 3372              0                   1      0         0       0    bs
#
#       total_count
# 11400           1
# 9562            1
# 5243            1
# 3777            1
# 3372            1
#
# [5 rows x 21 columns]

# %%
X_train[['text']].head()
# Out:
#                                                     text
# 11400  Who rode it best? Jesse Jackson mounts up to f...
# 9562   According to a new study, eight percent of our...
# 5243   What Happens If Trump LOSES The Election? What...
# 3777   The president and Hillary Clinton share a “stu...
# 3372   A 23 kiloton tower shot called BADGER, fired o...

# %%
import httplib, urllib, base64

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': 'b1b17649c5cb443a81c82343165d0a27',
}

# body = {
#   "documents": [
#     {"id": "1","text": "['\Today is a good day. It was a fine, bright evening. It made me very happy"
#     },
#     {
#       "id": "2",
#       "text": "Today is a bad day. It was not fine, dull evening. It made me very unhappy"
#     }]
# }

body = {
  "documents": [
    {"id":"1513","text": "[ \'This is the biggest story not being reported.\\nWhile the world teeters on the brink of World War 3, the media is reporting on Kim Kardashian.\\nMeanwhile the Russians are deploying the new Satan-2 missile (designation given by NATO).\\nEach Satan-2 missile has the power to devastate an area the size of Texas.\\nhttp://www.nbcnews.com/news/wo... \\nhttp://www.dailymail.co.uk/sci...\']"}]
}

print body

params = urllib.urlencode({
})

try:
    conn = httplib.HTTPSConnection('westus.api.cognitive.microsoft.com')
    conn.request("POST", "/text/analytics/v2.0/keyPhrases?%s" % params, str(body), headers)
    response = conn.getresponse()
    data = response.read()
    print data
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# {'documents': [{'text': "[ 'This is the biggest story not being reported.\\nWhile the world teeters on the brink of World War 3, the media is reporting on Kim Kardashian.\\nMeanwhile the Russians are deploying the new Satan-2 missile (designation given by NATO).\\nEach Satan-2 missile has the power to devastate an area the size of Texas.\\nhttp://www.nbcnews.com/news/wo... \\nhttp://www.dailymail.co.uk/sci...']", 'id': '1513'}]}
# {"documents":[{"keyPhrases":["missile","world teeters","new Satan","brink of World War","nEach Satan","Russians","power","Kim Kardashian","nMeanwhile","area","media","NATO","designation","size of Texas","biggest story"],"id":"1513"}],"errors":[]}

# %%
text_train = pd.DataFrame()
text_train = X_train[['text']]

# %%
text_train.reset_index(drop=True)
# text_train = text_train.drop('index')
# Out:
#                                                     text
# 0      Who rode it best? Jesse Jackson mounts up to f...
# 1      According to a new study, eight percent of our...
# 2      What Happens If Trump LOSES The Election? What...
# 3      The president and Hillary Clinton share a “stu...
# 4      A 23 kiloton tower shot called BADGER, fired o...
# 5      posted by Eddie Gun man have stolen a Dirty Bo...
# 6      VICE News Fri, November 18, 2016 10:38am URL: ...
# 7      Obamacare is working exactly as planned, and t...
# 8      Convinced that previous snow plowing policies ...
# 9      By Rahul Manchanda, Esq. on November 10, 2016 ...
# 10     Réunion du Conseil de sécurité du 28 octobre 2...
# 11     - < It’s Not Broken, So Let’s Break It–“Califo...
# 12     Who can argue with this young lady’s speech?\n...
# 13     ‘Go Back to Where You Claim Home,’ Kansas Lawm...
# 14     Prison Planet.com October 27, 2016 YUGE RECORD...
# 15     We Are Change \nThousands of wild American Bis...
# 16     Insider Leaks Bill’s 2-Word Nickname For Hilla...
# 17     Email Ever wonder what’s on the mind of today’...
# 18     November 11, 2016 ‘Trump’s election heralds co...
# 19     Headlines from Siberia reveal an incident of u...
# 20     \nZERO HEDGE \nWith furious Democrats - and th...
# 21     Is Trump the lesser of two evils or are both c...
# 22     Click Here To Learn More About Alexandra's Per...
# 23     Insurance Prices for Many Obamacare Customers ...
# 24     Zach Cartwright | November 11, 2016 \nThe Demo...
# 25     I'm not horrified she's with the Washington Po...
# 26     14 Shares\n4 9 0 1\nIt's a heartwarming moment...
# 27     link Well, that didn't go as planned... Anyway...
# 28     Two Systems of Justice In America: One for the...
# 29     Email \nThere was a time that the parent of a ...
# ...                                                  ...
# 10369  geoengineeringwatch.org \nThe power structure ...
# 10370  When I attempt to share your stuff on Facebook...
# 10371  Next Swipe left/right 16th century portraits t...
# 10372  BNI Store Oct 31 2016 “He is a pig,” says morb...
# 10373   Anthem\nRIP - Leonard Cohen Dead at 82\nVideo...
# 10374  The Modern History of ‘Rigged’ US Elections Oc...
# 10375  US election claims against Russia expose Clint...
# 10376  Carrier battle group never planned to call at ...
# 10377  President Obama has stooped to new lows in his...
# 10378  Waking Times \nIt’s always important to keep a...
# 10379  Era of Wisdom October 27, 2016 \nBrandon Turbe...
# 10380  YHC-FTSE Oct 26, 2016 5:14 PM \nWould have bee...
# 10381  This is vintage M. Kelly. People have been cal...
# 10382  “The ultimate measure of a man is not where he...
# 10383  By Top Right News on November 8, 2016 in Uncat...
# 10384  Click Here To Learn More About Alexandra's Per...
# 10385  As Aging Population Increases, Elders and Alli...
# 10386  NTEB Ads Privacy Policy Donald Trump, Bible Pr...
# 10387  Share on Facebook If gummy bears, peach rings ...
# 10388  Reality check media SYRIA: Heavy Fighting as R...
# 10389  Most College Students Think America Invented S...
# 10390  Print \nRick Ross was like a loud fart in a qu...
# 10391  By Tai Amri Spann-Wilson / 400yearsinbabylon.b...
# 10392  All is fair in love and war, and this particul...
# 10393  posted by Eddie Without much comment or fanfar...
# 10394  AB-Çin ilişkilerinde ABD ve NATO’nun etkisi ya...
# 10395  Deadline : \nDonald Trumpâs star on the icon...
# 10396  Subscribe \nThe Obama administration recently ...
# 10397  October 31, 2016 White House Press Secretary J...
# 10398  Posted 10/31/2016 3:41 pm by PatriotRising wit...
#
# [10399 rows x 1 columns]

# %%
text_test = pd.DataFrame()
text_test = X_test[['text']]
text_test = text_test.reset_index(drop=True)

# %%
# text_test['temp'] = 0
# count = 1
# for i in range(len(text_test)):
#     text_test.ix[i,'temp'] = count
#     count += 1
text_test.head()
# Out:
#                                                 text
# 0  This is the biggest story not being reported.\...
# 1  . This Ginger Tea Recipe Cleanses the Liver, D...
# 2  . NATO, US & UK Assemble Largest Troop Buildup...
# 3  November 18: Daily Contrarian Reads By David S...
# 4  We Are Change \nAs disturbing revelations abou...

# %%
text_test['id'] = 0
for i in range(len(text_test)):
    text_test.ix[i,'id'] = str(i)
text_test.head()
# Out:
#                                                 text id
# 0  This is the biggest story not being reported.\...  0
# 1  . This Ginger Tea Recipe Cleanses the Liver, D...  1
# 2  . NATO, US & UK Assemble Largest Troop Buildup...  2
# 3  November 18: Daily Contrarian Reads By David S...  3
# 4  We Are Change \nAs disturbing revelations abou...  4

# %%
blah = (text_test.to_dict(orient='records'))

# %%
j = text_test.groupby(['id','text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-223-3b20e053a1ed> in <module>()
#      11 # cList = []
#      12 # count = 0
# ---> 13 groupDict = outputDF.groupby('documents').apply(lambda g: g.drop('documents', axis=1).to_dict(orient='records')).to_dict()
#      14 for key, value in text_test.iteritems():
#      15     count += 1
#
# NameError: name 'outputDF' is not defined

# %%
a = BeautifulSoup(text_test.ix[0,'text'], "lxml").get_text()
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-250-eafc07007c84> in <module>()
# ----> 1 a = BeautifulSoup(text_test.ix[0,'text'], "lxml").get_text()
#
# /Users/abhishekvasu/anaconda3/lib/python2.7/site-packages/bs4/__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     163                     "Couldn't find a tree builder with the features you "
#     164                     "requested: %s. Do you need to install a parser library?"
# --> 165                     % ",".join(features))
#     166             builder = builder_class()
#     167             if not (original_features == builder.NAME or
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?

# %%
import httplib, urllib, base64
from bs4 import BeautifulSoup
import lxml
import re
import unicodedata
b = []
count = 0
# body = {
#   "documents": [
#     {"id":"1513","text": "[ \'This is the biggest story not being reported.\\nWhile the world teeters on the brink of World War 3, the media is reporting on Kim Kardashian.\\nMeanwhile the Russians are deploying the new Satan-2 missile (designation given by NATO).\\nEach Satan-2 missile has the power to devastate an area the size of Texas.\\nhttp://www.nbcnews.com/news/wo... \\nhttp://www.dailymail.co.uk/sci...\']"}]
# }
for j in range(len(text_test)):
    
    headers = {
        # Request headers
        'Content-Type': 'application/json',
        'Ocp-Apim-Subscription-Key': 'b1b17649c5cb443a81c82343165d0a27',
    }
    
    a = BeautifulSoup(str(text_test.ix[j,'text'])).get_text()
    letters_only = re.sub("[^a-zA-Z]", " ", a)
    letters_only = unicodedata.normalize('NFKD', letters_only).encode('ascii','ignore')
    
body = {
  "documents": [{"id":str(text_test.ix[j,'id']), "text": letters_only
}]}

#     print body

count += 1
#     if count == 5:
#         break

params = urllib.urlencode({
})

try:
    conn = httplib.HTTPSConnection('westus.api.cognitive.microsoft.com')
    conn.request("POST", "/text/analytics/v2.0/keyPhrases?%s" % params, str(body), headers)
    response = conn.getresponse()
    data = response.read()
    print data
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# {"documents":[{"keyPhrases":["world teeters","brink of World War","size of Texas  http   www nbcnews com news wo     http   www dailymail","new Satan   missile  designation","media","NATO","Russians","Kim Kardashian","power","uk sci","area","biggest story"],"id":"0"}],"errors":[]}
# {"documents":[{"keyPhrases":["homemade ginger tea  Ginger","Ginger Tea Recipe","s anti viral  anti bacterial  anti parasitic","kidneys  liver","upcoming cold season  Ginger tea","Liver  Dissolves Kidney Stones","cleansing tea","smaller quantities Drinking ginger","liver html Major health issues","course cancer","rise","diets     Print","types of cancer cells","body","circulation","http   humansarefree com","combating cold","rich","number of important things","stomach","headaches","minerals","vitamin C  magnesium","lifestyles","hell","sore muscles","superfood","risk of stroke","bodies","day","flu","vitamins"],"id":"1"}],"errors":[]}
# {"documents":[{"keyPhrases":["Russia  NATO","NATO troops","US allies NATO","NATO  US   UK","cold war  NATO","NATO officials","NATO military divisions","NATO  Douglas Lute","range of NATO   s deployment","specific operation  NATO","Russia   s borders","US military claims","US government","Provoking Russia","http   humansarefree com         nato us uk","Cold War  Cold","largest military buildup","conflict     NATO Secretary General Jens Stoltenberg","military tensions","Russian Border","Russia   s  security posture     Lute","previous Cold War","biggest military","world war","Russian troops","huge military deployment","s lands","ongoing proxy war","Largest Troop Buildup","Mexican border","largest troop html","United States    envoy","European states","largest mi    Print","total of     troops  drones","midst of deepening tension","nuclear warheads","presence of nuclear weapons","weeks","targets","regime change","Poland","country","Italy  France  Denmark","Iskander M cruise missiles","threat","result","funding violent rebel groups","Kaliningrad","type of situation","Syrian government","forces","reporters","statement","Tuesday","control","allied governments","army","Western powers","coming days","credible deterrence","Baltics","WW","addition","tanks","Estonia","John Vibes","effort","superpowers","odds","Wednesday  Britain","facto provocation","equipment","soldiers","hardware","time","Reuters","miles","home","ready","deterrent","parties"],"id":"2"}],"errors":[]}
# {"documents":[{"keyPhrases":["November     Daily Contrarian Reads","David Stockman","Friday  November   th"],"id":"3"}],"errors":[]}
# {"documents":[{"keyPhrases":["Clinton   s campaign","s blood  sperm","Hillary   s sessions","Hillary Clinton   s inner circle","candidate   s favorite dead friends","wife   s conversations","candidate   s inner circle","post Hillary Clinton","therapeutic release      Clinton   s bizarre pastime","Hillary s campaign launch   SpiritCooking https   t","KiiraDh      WikiLeaks   wikileaks  November","Wikileaks revelations","Nancy Reagan   s use of astrology     Woodward","rhinoceros     Mrs  Clinton","Lady  Bill Clinton","blood  https   t","hVbiefAvIt pic","November           Abramovic","earthquake nights      CassandraRules  SpiritCooking  podestaemails    WikiLeaksPhase   PodestaEmails  SatanicHillary  wikileaks    WikiLeaks  MAGA X pic","fresh sperm","Cooking  dinner","Trump      DeplorableDan   November","com rwAOpo FaS      Aussies","Spirit Cooking     dinner","woman","Eleanor Roosevelt","director","gGPWFS B H pic","occult blood rituals","com  cW nw AZs      Johnny Ringo   JR","Bob Woodward","recipe","campaign chairman John Podesta","point     mix fresh breast milk","occultist Marina Abramovic","column","massive concerns","disturbing revelations","damaging comparisons","Foundation","advisers  Jean Houston","performance artist","Mind Research","people","White House","Podestas","brother","book","spirit dinners","shocking video","Jesus Christ","breastmilk","Mahatma Gandhi","seeking advice","dark things","speech","Choice","Friday","discussion","appropriate time","penchant","meetings"],"id":"4"}],"errors":[]}
# {"documents":[{"keyPhrases":["nan"],"id":"5"}],"errors":[]}
# {"documents":[],"errors":[{"id":"6","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["new  Moon","Solar Lunar Month","Solar Lunar Year","Libra lunar cycle","Libra  Aspect","shift  New","Wind  Goddess","cardinal signs of Aries  Libra  Cancer","loss of self esteem","visionary   Sabian Symbol","minimizing inner promptings  fear of change  lack","Beginnings  Matangi  Goddess","Change  escapism  old stories  poor loser  prejudice","Aeon Sophia  Wisdom   Kali  Goddess of Endings","Aeon Thelete","Elias  God","range of conjunction   Sabian Symbol","special room","Way  Aspect","masters","outer signs","art gallery     light","magic carpet of Oriental imagery     transcending difficulties","corner   Light","Medicine Wheel","battle","life  expansion of perceptions  linking mind  body","spirit  vision","directions","cardinal points","unraveling control paradigm  fantastical experiences","Balsamic Moon Phase  release  dream","emotions  miscommunications","West  God of Alchemy  Skill","inner voice  True Alignments","Capricorn  major shifts","indecision","lives","misunderstandings","Mercury","corners","good riddance  wonderment","Catalysts","final push","mettle","degree","things","world","compass","days"],"id":"7"}],"errors":[]}
# {"documents":[{"keyPhrases":["existence of alien life  UFO   s","s possible","earth   s atmosphere","s logical","today   s era","Weird      Comments NASA   s space cameras","UFO phenomena","object   UFO","UFO phenomenon","question isn   t","NASA didn   t","alien spacecraft","disk shaped UFO","planet Earth","Space Shuttles","American Physician  retired NASA astronaut","space agency","air space","YouTube","advanced civilizations  intelligence  life","visiting earth   Ancient Code reports","Theodor C  Loder III  Ph D   Professor Emeritus of Earth Sciences  University of New Hampshire","existence of UFOs","retired Captain","Star People","astronauts  military officials","Musgrave","Apollo astronauts","crafts","extraterrestrial beings","founder","new evidence","US Navy  aeronautical engineer","fragments of videos","fact","Intelligent beings","live feed transmissions","mystery objects","bodies","Institute of Noetic Sciences  IONS","design","occasions","extraterrestrial object","scientists","numerous fascinating statements","Dr  Edgar Mitchel","user","certainty","Edmondo Burr","star systems","long time      Franklin","Skylab Program","theory","subject","interesting things","footage","moon","joke","aliens","matter of conjecture","truth","development","massive conspiracy","interstellar travel","suspicion","man","universe","taxes","Visitors","cosmos","strange sights","virtue of association","idea","controversy","point"],"id":"8"}],"errors":[]}
# {"documents":[{"keyPhrases":["video  Pieczenik","U S  administrations  Pieczenik","United States Department of State official Dr  Steve Pieczenik","high level pedophile ring  Pieczenik","Democratic Party    Fixer     Jeff Rovin   Dr  Pieczenik","Hillary Clinton","Deputy Assistant Secretary of State","military officers","details","FBI investigation","intelligence community","WikiLeaks     US intelligence","capacity of deputy assistant secretary","Anthony Weiner   Jeffrey Esptein   s Lolita Express","data","resolving international crises","military  law enforcement","foreign policy  international crisis management","Clintons    connections","government","videos   Click","Editor   s Note","expertise","White","presidential administrations of Gerald Ford","Carter  Ronald Reagan","James Baker","judiciary","counter coup","Daily Sheeple","Julian Assange","Henry Kissinger  Cyrus Vance","psychological warfare","George H W","new boss","reports  analyses  breaking news","corrupt couple","series of videos","information","psychiatrist","central facets","Donald Trump","campaign","years experience","opening","Russians","sides","American revolution","tens"],"id":"9"}],"errors":[]}
# {"documents":[{"keyPhrases":["que es en realidad","encontrarse en","mujeres  Son personas que","misma manera que","ni  ez  ya que las personas que durante","poco conocido que puede convertirse en","anorexia sexual tiene su origen en","definici  n que el doctor Patrick Carnes propuso en su libro  Anorexia sexual   publicado en       es","estado obsesivo en el cual","trabajar en una interconsulta","anor  xico sexual es alguien que evita el contacto sexual porque tiene aprensiones","hacia personas   En algunas ocasiones","origen muy profundo que podr","inapetencia sexual puede tener causas serias que","llamada  anorexia sexual  es","sus deseos sexuales    Hay soluci  n   El problema es cada vez m  s frecuente  pero tiene soluci  n   Los problemas que tienen que ver","manera que proyectan sus deseos sexuales hacia","producci  n er  tica en forma","alguien     Los anor  xicos sexuales son aquellas personas que para evitar","evitar el sexo domina","cualquier placer sexual porque","psicoterapeuta sexual Natalia Guerrero  El origen del trastorno  El extra  o trastorno afecta tanto","anor  xico evita comer porque cree que est   m  s gordo","convierten en una grave enfermedad  Imagen Ilustrativa Pixabay   Takmeomeo S  guenos en Facebook","acosos sexuales en el futuro pueden sufrir el trastorno  Las mujeres violadas tambi  n evitan las relaciones   ntimas durante mucho tiempo  mientras que algunas personas renuncian al sexo tras haber sido rechazadas por los objetos","perciben como una amenaza  Los psic  logos apuntan que las causas del fen  meno tienen","veces el problema forma parte","quieres tener sexo  Publicado     oct            GMT  En nuestro siglo","plaga del siglo XXI    Seg  n","v  nculo m  s profundo","sociedad contempor  nea  Las personas simplemente","trastorno todav","psiquiatra  porque","genes y videos y","plaga del siglo XXI    por qu","una terapia sexol  gica   pero cuando los casos son muy graves  se requiere","fobias m  s generales   afirma Guerrero","saben construir relaciones y recurren","esta esfera se pueden trabajar","tarea f  sica  emocional y mental","hombres como","sentir deseo  se proh  ben disfrutar","intimidad reh  yen cualquier tipo","infancia fueron v  ctimas","revistas  pel  culas e Internet","car  cter psicol  gico   explica","cuadro","pesar","vida"],"id":"10"}],"errors":[]}
# {"documents":[],"errors":[{"id":"11","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["Trump   s intentions","Trump   s Election  Beware","campaign promises   Paul referenced Trump   s independence","Shadow Government","terrorism     Paul","election of Donald Trump","billionaire businessman  Trump","Ukraine   Paul","JFK   s assassination","administration   Ron Paul","Daily Sheeple    Editor   s Comment","apparent government","presidential candidate Ron Paul","work","shadow powers","terrorism  war","Deep State","Middle East","office of power","lot of pressure","lot of influence","darkest interests","secret power structure","divided population","term","foreign policy  America","world affairs","secret societies","playing ball","Oval Office","article","cabinet","favorable outcome","outside source","Russia","big leagues","people","big boss","congressman","advisors","US presidency","hidden power structure","Wikileaks release","NATO alliance","decades","tremendous test","dominion","Hillary Clinton","situation","right direction","global economy","view","attempt","advice","appointees","Podesta emails","political outsider","serious characters","major skepticism","fact","ISIS","neoconservatives","elections","good sign","little bit","History","background","watch","control","citizens","wars","time","guy","hopes","instance"],"id":"12"}],"errors":[]}
# {"documents":[],"errors":[{"id":"13","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["federal ban","called assault weapons ban","s era gun ban isn   t","assault weapon  ban hits record low","U S","percent of Democrats","Increasing opposition","Republicans  Gallup   s data","level of opposition","new Gallup poll","percent of American adults","Republican support","Wednesday","guns Published    mins","law","independents","years","board"],"id":"14"}],"errors":[]}
# {"documents":[{"keyPhrases":["LEAKED  Brexit High Court documents","MPs","vote","Article    judgment","parliamentary approval","motives","Prev","judgement","Government"],"id":"15"}],"errors":[]}
# {"documents":[],"errors":[{"id":"16","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[],"errors":[{"id":"17","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[],"errors":[{"id":"18","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[],"errors":[{"id":"19","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["cause  North Korea policy","AFP   Frank SmithSouth Korea","Washington s pressure policy","South Korean officials","Japanese counterparts","TV  American  Japanese","leading US intelligence chief","policy of sanctions","Thu Oct              PM US Secretary of State John Kerry","New York  September","Pyongyang","unseen","trilateral meeting","Tokyo","week","policies","effective"],"id":"20"}],"errors":[]}
# {"documents":[{"keyPhrases":["Liberty Writers reports  Mike Pence","MOVIE  MIKE PENCE","t recall","new level","IWB    October           Danny Gold","politician","people","TRUMP RALLY","faithful","AMAZING","love"],"id":"21"}],"errors":[]}
# {"documents":[{"keyPhrases":["TRUMP VICTORY"],"id":"22"}],"errors":[]}
# {"documents":[{"keyPhrases":["Trump   s record","s deflections of Hillary   s jabs","Donald Trump   s debate prep","Trump   s use of pejoratives","Nation   s Abuser","Chief Trump","cornerstone of Trump   s political speech","candidate   s penchant","aren   t","didn   t","Hillary Clinton   s husband of sexual misconduct","Bill isn   t","apology t hat wasn   t","Donald Trump insult generator","past isn   t","arbitrary   Oh  Hillary doesn   t","video of Trump boasting","assaulting women","emotional abuse survivor","president   Emotional abuse","jail     Donald","Bill Clinton","example  accusing Hillary of laughing","Republicans   Poor Donald","Crooked Hillary  Lyin    Ted Cruz  Little Marco Rubio","live TV audience","negative remarks","blog Live Bold","cutting remarks","calling","making fun","expression","affairs","locker room","bully","media","Clintons","Energy Jeb Bush","subtle threats","conspiracy","long list of things","hand","best way","fact","rape victim","abusive partner","breath","eerie feeling","glass houses","stones","Khalil Bendib","OtherWords cartoon","qualifications","action","lived experiences","item","film","gaslighting","question","critique","issue","misogynist","mind","past bad behaviors","Pocahontas","checklist of    tactics","disabled reporter","telltale signs of","responses","problem","Elizabeth Warren","names","history","entire world","intent","personal responsibility","valuable service","time","life","difficulty","friends","humiliation","people"],"id":"23"}],"errors":[]}
# {"documents":[{"keyPhrases":["police officers","police force","Brink  Police","November          Sweden","region   s police association","summer  Sweden","new officers","Sweden   s National Criminal Investigation Service","World War Sweden","union   s","southeast of G  taland      G  taland","resources echoes National Police Commissioner Dan Eliasson   s February warning","growing migrant crisis","country   Thomas Stjernfeldt","Scandinavian country","existential crisis","Violence","reported crimes","attempted murder   Mr Stjernfeldt","suspected crimes","areas","rapes  murder","Migrant Influx Lizzie Stromme","population","series of brutal crimes","violent incidents","unprecedented levels of crime","arsonist attacks","alarming trend","New Years","recent years","assaults   drug dealing","figures","number","city of V  xj","weapons","uk","political right","helping migrants","south east","reasonable working environment","ability","battle","borders","children","resignations","Monday  Express","zone    list","moves","situation","specialist staff","SVT","public","September  Swedish officials","lawless state","control","asylum applications","citizens","faith","cases","breaching point","regions","operational sector","refugees","car"],"id":"24"}],"errors":[]}
# {"documents":[{"keyPhrases":["FBI investigation","opening investigation","new investigation","previous Clinton investigation  NBC News  FBI","FBI   s email investigation    story","harassing Clinton","Clinton https   t","Hillary Clinton   s private e mail server      Jesse Rodriguez   JesseRodriguez  October","big story","NBC   s Pete Williams  Sr  officials","Hillary supporters","QmmNoxXhOx      Bradd Jaffy   BraddJaffy  October","reopening","isn   t","baseless accusations  FBI Director James Comey","Trump       Hallie Jackson   HallieJackson  October","official announcement  NBC News","MSNBC  veteran reporter Pete Williams","hungry reporter","Alex Wong Getty","hours","initial headlines","big    things","way","campaign","Featured image","Republican colleagues","Like Wikileaks","new emails","gamechanger","desperate Republican","dud","evidence of criminal wrongdoing","maddening world","fresh controversies","small update","non scandal","political points","Watergate","conservative movement","Article","meaningless victory","election","pretext","appearance","case","device","hopes","concrete proof","bombshell","Republicans"],"id":"25"}],"errors":[]}
# {"documents":[{"keyPhrases":["food supply","month   s supply of food","Clinton   s war","scarce  food","year   s worth of storable food","Sales of emergency survival food","s important","increase of sales of long term food","survival food companies","survival food company","emergency food market","long term food suppliers","Hillary Clinton   s coronation","Russia   s involvement","election time","U S  Economy   s Bubble Of False    Silver Bullion","election day","election season","storing large amounts of non perishable food","Gear Sales","sales triple","post election unrest","declaration of war","long term storable foods","non existent Cold War","specific election outcome","Long term Bartering","possible World War   scenario","Store owner Larry Friedman","military surplus supply store  M G","Times  Riot","Scud missiles","Trump rally","candidates    policies","doors","Desert Storm  People","Legacy Foods","hands","violent riots","Donald trump","November  th       Sign","life","rhetoric","liberty","government related threats","country","Patriot","large spike","called protesters","owner Phil Cox  Legacy","fly zones","original invasion of Iraq","gas mask","major threats","Ready Nutrition","establishment","military grade Mylar packs  Retailers","phones","Bensemer","Keith Bansemer  marketing VP","package","Syria","democrats hellbent","presidency","freedom  Bansemer","serving bucket","air space","San Jose   California outside","increased presence of preppers","chemical weapons","guns","meals","customer base","Aleppo","couldn   t","resulting chaos","gun confiscation","possibility","NBC news","Prepper       Reasons","number of","good reason","disaster strikes","regulars","EMP Weapon","primary currency","information","decades","desire of politicians","opportunity","market  Costco","concern","signs","amendment","business","weeks","matter","revolt","positive step","question","hook","apocalypse"],"id":"26"}],"errors":[]}
# {"documents":[{"keyPhrases":["kids   Kaepernick","country     Kaepernick","free youth camp","Saturday  Kaepernick","sports   Kaepernick","camp evidence","Camp site","Oppression Colin Kaepernick","education based camp","local youth","Kaepernick   s bold choice","Home    Solutions   Colin Kaepernick","national anthem  San Francisco   ers quarterback Colin Kaepernick","Black Panther Inspired Youth","Undefeated   kids","youth level","policing history","history of policing","don   t","police departments","quiet police brutality","aren   t members","epidemic of police brutality","New York Daily News","Daily News reporter Shaun","athlete didn   t","daily basis","organic nutrition  holistic healing  financial knowledge  higher education","higher education  self empowerment","local leaders  local activists","past history","systems of policing","program   s goal","safe","knowledge based confidence","San Francisco Bay area","change","original Black Panthers       point","Oppression Claire Bernish November           Comments  Oakland  CA","free campaign","website","distrust uniformed officers","Nigeria","kits","stronger generation of people","roots","Ghana","awareness","Latino children","speakers","lot of movements","ancestry","instruction","smaller breakout","publicity stunt","number of homeless children","law enforcement","soaring praise","lot of hope","fundamental rights","protest","charge","plans","sessions","halfway house","various scenarios","civilians","burning ire","world      Controversy","contrary","details","attendees","positive force","single workshop","place","relations","simple cameo appearance","oppressive issues","communities","words","media event","days","cities","goals","America","families","skills","culture"],"id":"27"}],"errors":[]}
# {"documents":[],"errors":[{"id":"28","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["Arkansas","step","North Dakota","ballot measures legalizing medical marijuana","Mike Maharrey Voters"],"id":"29"}],"errors":[]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 43 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 43 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 43 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 42 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 42 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 42 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 41 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 41 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 41 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 40 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 40 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 39 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 39 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 39 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 38 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 38 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 38 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 37 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 37 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 37 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 36 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 36 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 35 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 35 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 35 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 34 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 34 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 34 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 33 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 33 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 33 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 32 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 32 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 32 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 31 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 31 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 31 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 30 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 30 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 30 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 29 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 29 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 28 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 28 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 28 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 27 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 27 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 27 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 26 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 26 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 26 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 25 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 25 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 25 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 24 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 24 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 23 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 23 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 23 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 22 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 22 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 22 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 21 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 21 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 20 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 20 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 20 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 19 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 19 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 19 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 18 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 18 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 17 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 17 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 17 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 16 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 16 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 15 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 15 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 15 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 14 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 14 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 14 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 13 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 13 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 12 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 12 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 11 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 11 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 11 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 10 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 10 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 9 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 9 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 9 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 8 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 8 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 8 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 7 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 7 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 7 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 6 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 6 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 5 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 5 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 5 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 4 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 4 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 3 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 3 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 2 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 2 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# {"documents":[{"keyPhrases":["President Hillary","Oligarchy Hillary","new hillary","Hillary presidency","FBI investigation of Hillary","overweighting Hillary supporters","reopened Hillary email case","Oligarchy   s interests","America   s reputation","Jeffrey Epstein   s Boeing","Epstein   s    acre island","FoxNews com     Clinton   s presence","President Bill Clinton","registered sex offender   s infamous jet","US Rep  Weiner   s computer","NYPD pedophile investigation","U S  Virgin Islands     http   www foxnews com us            flight logs","election theft","oligarchs","sex offenders jet","House Committee","additional FBI investigations","White House","House Speaker Paul Ryan","government  Chaos","young girls      Fox News reports","felony investigations","flights  http   truepundit com","money laundering sex crimes","case  Americans","Clinton Foundation","time","reply  Paul Craig Roberts","insouciant Americans","bombshell nypd","helm  SF Source Paul Craig Roberts","FBI Director Comey","election fraud experts","image of America","new meaning","samples","Government Reform chairman Jason Chaffetz","oversight","theft claim  Electronic voting","trips","related scandals","world","Little St  James","years worth of material","solicitation","whistle","children child exploitation","credibility","prison","Oval Office doesn   t","group","kind of behavior","agent","fellow passengers","weeks of hearing poll results","perjury","html","big hit","kind of scrutiny","included extended junkets","salacious scandals","Internet sites","estate","United States","person","good decision","kind of pressure","procurement of minors","exceptional nation","elections","asset","frequent flyer","prostitution","polls","occasions","Secret Service","reopening","Lolita","American people","cover","lead","explanations","Oligarchic power","purpose","country","target rich environment","confidence","initials","attorney general","Tatiana","names","various connections","Senate","Nabakov inspired nickname","stage","example","Orgy","indictment","records","Donald","team of traffickers","point","emails","evidence","liability","friends","words","Trump","Republicans","Richard Nixon","bed","spotlight","number"],"id":"145"}],"errors":[]}
# {"documents":[{"keyPhrases":["turret bustle  rear","armor","forward facing parts","ready ammunition stores","Abrams tank","Kornet"],"id":"146"}],"errors":[]}
# {"documents":[{"keyPhrases":["female bishop","crowd shot","sec clip of Archbishop s historic announcement","end    pic twitter com tJZZO xQdv      Kaya Burgess   kayaburgess  November","Wales","underwhelming crowd","people","Church","Prev"],"id":"147"}],"errors":[]}
# {"documents":[{"keyPhrases":["monkey   s breathtaking ass  Red monkey asses","hulking red monkey ass","bright red ass","huge red ass","red assfest","inflamed red monkey asses","giant red asses","swollen red asses","bloated red miracle","bulbous red buttocks","majesty of nature","Earth   s history","humanity   s place","isn   t","bright asses","entire red assed money wad","list of beautiful nature photos","don   t","gaggle of monkeys","amazing ability","Alaskan wood frog","thaw","largest animal","hummingbird moth","winter","Chimpanzees","Gal  pagos tortoise","blue whale","power of evolution","end","impressive example","real showstopper","simple tools","remarkable specimens","sticks","termites","beacon","years  Incredible","spades","creature","glance","way","planet","closest cousins","diligence","siree","eyes","deck","readers","meantime","science fiction","intelligence","Email","weather","dinosaurs"],"id":"148"}],"errors":[]}
# {"documents":[{"keyPhrases":["specific US intelligence","US intelligence officials","Foreign Intelligence Surveillance Act  intelligence agencies","US authorities","Yahoo  Order","foreign intelligence gathering efforts","government s surveillance activities","letter","public","classified US government directive","Director of National Intelligence  DNI  James Clapper","Yahoo s website","government requests","Clapper s office","Yahoo Mail accounts","specific information","user data","customer data","extent of electronic surveillance","governmental authorities","users  private information   Citizens","custom software program","statutory limits","Reuters report","democracy","ACLU motion   judicial opinions interpreting constitutional","American phone","Thu     Oct            UTC    sky   ddns net Yahoo","statutory basis","group","disclosures","national security orders Washington","wasn t","American Civil Liberties Union  ACLU","set of circumstances","variety of reasons  including prevention of terrorist attacks","unknown number of legal opinions","NSA whistleblower Edward Snowden","release of court records","mail scanning","recent press reports","DNI head","spokesman","controversial document","media reports","FISC","systems   Timothy Barrett","revelations","amendments","customers  incoming","following actions","internet companies","relevance","clarity","rule of law","stronger precedent of transparency","constitutionality","October","matter","alleged facts","privacy rights  Comment","laws","article","Wednesday","inspection","explanation","company","appropriateness of"],"id":"149"}],"errors":[]}
# {"documents":[{"keyPhrases":["Mosul of Daesh terrorists","Mosul operations","Reuters   Daesh","particular     Daesh","Qayyarah  south of Mosul","Iraqi security forces","Iraqi city","advancing Iraqi forces","Iraqi army","Daesh held areas","government forces","Mosul   Iraq   s Joint Operations Command","Iraq army forces","terrorists  Federal police forces","Takfiris gains momentum    Daesh militants","different areas of Mosul   saidthe chairman","Iraq Federal police forces","volunteer forces","October            Shamri","October            Photos","Iraqi Prime Minister Haider al Abadi","human rights office","Iraqi parliamentary human rights committee  Abdel Rakhim Shamri","past week  Federal police forces","Dirik village","October            Earlier  military sources","Iraqi counter terrorism units","human shields","villages of Saf al Tuth","village of Arij","human rights spokesman Rupert Colville","Tuloul Naser village","airlifting of civilians","General Najm al Jabouri","bodies of    civilians","Wednesday","Nineveh provincial council  Abdul Rahman al Wagga","police officers","area of       Hammam al Alil","kilometers","resident of Nana village   Regional officials","military vehicle","scorched earth policy","Iraq  Loading","kidnapping","executing people","large military offensive","province of Nineveh","explosives","hostage","member","buildings  farms","villages   Locals report","lot of people","industrial plants","idea","commander","Peshmerga fighters","rocket","briefing","pickup trucks","enemy snipers","atrocities","called headquarters","clashes","Tuesday","scores of mass killings","country","town of Bashiqa","bullet wounds","Geneva","beginning","terror group","families","fate","battle","executions","brother"],"id":"150"}],"errors":[]}
# {"documents":[{"keyPhrases":["s kind","raw eggs","clipper   s mast","jackal   s mouth","arms","Frank Sinatra  John Travolta   s dad","Greatest Generation","civil rights","don   t","particular word","isn   t","nationality","wouldn   t","tie","ranks","World War II","kind of dignity","long  terrible teeth","previous holder","gratification","Dagwood","outdoor silk","hood","car","yesterday Email","hideous Tasmanian tiger extinct","tongue","differences of race  creed  sex","awful strength","wash","set of meanings associated","Blondie","feet tall","best way","afternoon","title","idea","legs","age","gotta","tarp","morning","house","sundown","pets","Bruce","poise","Ways","person","fight","room","radio","appetites","Leland","folds"],"id":"151"}],"errors":[]}
# {"documents":[{"keyPhrases":["US economy  Soros","NDAA","electoral college   Soros","Previous Rendition George Soros","US Special Operations forces","American Special Forces","Humanity","American people","guilty of election tampering","rendition facility","criminal   s  criminal","Crimes","guilty of terrorist economic tampering","video","bribe  election fraud","impassioned appeal","deep dark hole","voters","phone","action","lawyer","day","repayment","court","United States","alien  enemy combatant","behalf","endeavor","furtherance","Nazi collaborator","Dave Hodges","world"],"id":"152"}],"errors":[]}
# {"documents":[{"keyPhrases":["private  POTUS","drug dealers  POTUS","Duerte shouldn t","mouth","conversation","world stage","consequence"],"id":"153"}],"errors":[]}
# {"documents":[{"keyPhrases":["Guest Click","article","Posted  Nov   th"],"id":"154"}],"errors":[]}
# {"documents":[{"keyPhrases":["Jungle resident   French Foreign Legion troops","French Foreign Legion forces","alien jungle creatures","ze jungle  non si vous","French zoos","outstanding victory  Jungle inhabitants","ze bush","Foreign Legion Baguette Bashers","pots   French President  Francois Hollande","ze world zat","English Channel  Passengers","lumps of stale  tasteless English sandwiches","watering holes","school of passing hump","tech baguettes","stale garlic breath    Messieurs","pieces of stinking camembert","dire need of nourishment","UK s surrounding seas","superb  historical victory","Madames  France","safety of urine saturated trees  bushes","ferries","Francois   Qui","whales","natural instincts of scavenging sea gulls","course  Make Jaggedone s","real weapons","Bulgaria","curly haired heads","Normandy Invasion","attack","crumbs  Inhabitants","Sunday     October","board","huge fishnets","Tricolore","country","week","statement","island"],"id":"155"}],"errors":[]}
# {"documents":[{"keyPhrases":["didn t","Rudy Giuliani  Newt Gingrich  Adolph Hitler  Adolph Hitler s son","hadn t","hasn t","Trump s racism","harsh criticism","Constitution    NBC News","news station","Make Jeff Brone s day","people","Donald Trump","Whipperford Post website","week","reporters","Cerberus","Skip Homeyer","guy","election","citizen","story","names","job","excuse","office","campaign promises","media","ll","president","team","thumbs"],"id":"156"}],"errors":[]}
# {"documents":[{"keyPhrases":["SHTFPlan com","Daily Sheeple of www TheDailySheeple com","election  Kim Dotcom","heat","YouTube  Sources   Internet Mogul Kim Dotcom","Shoulders     Obama","Ohio Troopers","Coming     Clinton","Jeremiah Johnson","videos   Click","Orbit","Earth","Asgardia    Space Nation","Weeks","Republic","United States","American History  Objections","State Department Official Steve Pieczenik","post selection","details","author","Impassioned Plea","government","bubbas","North Dakota","President Obama","reports  analyses  breaking news","SKY Conspiracy Theorists","attribution","game changing event","link","Trump","Serious Trouble","Future","time","Fate","content","Illuminati","digital form","Fronts","things","Clintons"],"id":"157"}],"errors":[]}
# {"documents":[{"keyPhrases":["new US Administration readies","China s reclaimed islands","South China Sea area","distinguished US diplomat  Ambassador Charles Freeman","chance","coast","s Liberty Report","Middle East","credit","live link","RonPaul Institute  Permission","Russia clash","rest","odds","Syria policy","spots","diplomacy","major wars","Daniel McAdams","neocons","issues"],"id":"158"}],"errors":[]}
# {"documents":[],"errors":[{"id":"159","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["Miller   s staff","polls  Miller   s tweet","lawmaker  Miller","Sid Miller character","possible  Commissioner Miller","level   Meet Sid Miller","s number","reason Hillary   s emails","Hillary Clinton","Republicans  doesn   t","little woman doesn   t","Texas Republican","state of Texas","Right","Texas Tribune","disgraced Congressman Anthony Weiner   s sexting scandals","TRUMP    Cunt","Agriculture Commissioner","perfect Donald","display","term vulgar","post","screen","retweeting information today","women","Daily Beast","fact","hatred","supporter","sexism","election season","defense","derogatory term","feelings","major party","Oval Office","campaign","writing","words","health","stamina","disgusting way","offensive jokes","ignorant asshat","course  code","news","relesed","misogynists","reference","history","image","retweeted","account","misogyny","Article","predictable firestorm","hours old","idea","secret","Twitter","problem"],"id":"160"}],"errors":[]}
# {"documents":[],"errors":[{"id":"161","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["Treasure Secretary","Homeland Security Secretary","Secretary of State  Mnuchin","afraid of Sheriff Clarke  afraid","course Sheriff David Clarke","haven   t","CNN commentator Angela Rye","terrorist inciting terrorism","Blue Lives Matter  CNN","comment section","leader","year veteran of Goldman Sachs","s terrorism","people","major flag","Attorney General","Mayor Giuliani","Gingrich","Politico","names","Facebook page","policies"],"id":"162"}],"errors":[]}
# {"documents":[{"keyPhrases":["China   s national security","China   s eastern beach","China   s Global Times","armadas of China   s People   s Liberation Army","U S","world   s super powers   China   s state run media","nation   s power","post Brexit world  China","South China Sea waters","coming World War III   China","nation   s East  North","November      Ads RED ALERT  China","Chinese military","United States","national sway","military    run National Defense University","military  police","military ties","danger   Wanquan","national protection issues","Russia","South Seas","matters of sway      Wanquan","Chang Wanquan","army bases","Defense Minister","security device","regional uprightness","state controlled blogging website  Lian","considerable length of time","Weibo","regional respectability   Pundits","gravity of danger","seaward security dangers","teacher","Australia ventures","trust","territory","ammo drills","strike","region of Zhejiang","boats","fact","citizens","adventure","caution","advantage","Oct          Previous post","July","Permanent Court of Arbitration","subjects","light","solid conviction","need","ought","perfect focus","Philippines","expression","neighbors","WW","tensions","assembly","protective capacities","natives","risky probability","measures","rant","partners","submarines","affirmation","guide","situation"],"id":"163"}],"errors":[]}
# ...
# {"documents":[{"keyPhrases":["African American citizen","African Americans","strong African American community","black America   Trump","US President","new deal","city of Charlotte","campaign rally","Opinion Article  Trump","communities  safety","creating safe communities  great education","children  Republican presidential nominee Donald Trump","crime     REUTERS  Mike Segar Half of US Voters Concerned","Charlotte  North Carolina   WASHINGTON  Sputnik","greatest champion      AP Photo  Don Ryan Black Lives","trial","Clinton","Activist","high paying jobs","young white racist Dylann Storm Roof","United States","Potential Violence","future","country","mass murder","vision","honor","church","Election Day","privilege","Bible study","year","Wednesday","site","point plan","economic prospects","URL","principle","beginning"],"id":"1003"}],"errors":[]}
# {"documents":[{"keyPhrases":["Miller   s staff","polls  Miller   s tweet","lawmaker  Miller","Sid Miller character","possible  Commissioner Miller","level   Meet Sid Miller","s number","reason Hillary   s emails","Hillary Clinton","Republicans  doesn   t","little woman doesn   t","Texas Republican","state of Texas","Right","Texas Tribune","disgraced Congressman Anthony Weiner   s sexting scandals","TRUMP    Cunt","Agriculture Commissioner","perfect Donald","display","term vulgar","post","screen","retweeting information today","women","Daily Beast","fact","hatred","supporter","sexism","election season","defense","derogatory term","feelings","major party","Oval Office","campaign","writing","words","health","stamina","disgusting way","offensive jokes","ignorant asshat","course  code","news","relesed","misogynists","reference","history","image","retweeted","account","misogyny","Article","predictable firestorm","hours old","idea","secret","Twitter","problem"],"id":"1004"}],"errors":[]}
# {"documents":[{"keyPhrases":["s International Agency","U S  institutions","scientists","U S  FOIA laws   Glyphosate","Cancer  IARC","glyphosate research","Monsanto   s weedkiller Roundup","documents","News   US","carcinogenic      Makers","IARC decision","carcinogenic   Agweb com reports","Freedom of Information Laws","product","disclosing information","World Health Organization","key ingredient of Roundup","calling","Sean Adl Tabatabai","weed killer","study","property   Reuters","parties","letter  officials","response","groups","dangers","claim","lawsuit","case","panel"],"id":"1005"}],"errors":[]}
# {"documents":[],"errors":[{"id":"1006","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# {"documents":[{"keyPhrases":["Video","North Dakota","Dakota Access Pipeline","massive sense of shame","sense of Justice Permalink  Page   of   pages      fans    Advertisement","pipeline construction  Bernie Sanders","pepper spray","complete cessation","Unicorn RIot TV  License DMCA   Advertisement","violence   image","Today","aggressive ways","stop","sickening footage","Obama","OpEdNews Op Eds","solution","corporations","people","nation of oppressors","stomachs","using tasers","outrage","native defenders","Rights of Indigenous","mainstream media","friends","groups","Senator","crime"],"id":"1008"}],"errors":[]}
# {"documents":[],"errors":[{"id":"1009","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[],"errors":[{"id":"1010","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# {"documents":[{"keyPhrases":[""],"id":"1012"}],"errors":[]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# {"documents":[{"keyPhrases":["true cost","free articles","Bn","National Living Wage"],"id":"1014"}],"errors":[]}
# {"documents":[],"errors":[{"id":"1015","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# {"documents":[{"keyPhrases":["November  th  Trump   s election","Donald Trump","viral  Trump","DNC     Hillary Didn   t","car   s","s   minutes","schmo wouldn   t","liberal   s liberal","validating of Trump   s entire campaign","ears of people","election crystal","average voter  doesn   t","Trump  Corporate America","posturing  Obama hasn   t","decent people","fault  People","s kind of irrelevant","middle class loves Trump","November  th     Election Day","Hillary Protesters","system","Michael Moore","rush election film Trumpland","Hillary Clinton","damned thing","ultimate    F","f  king percocet","big f  king X","Ohio","DNC Convention","amazing thing","DNC Officials","biggest F  K","Nomination","American Constitution","human history","com UOgqSfet","lives  Donald J","Protesters Rage","Wall Street","Pennsylvania","matter","box","human hand grenade","human Molotov cocktail","pivotal point","actual problems","leaders","EarlyVoting pic","electoral college","touchscreen","ballot","smiles","Jared Wyand   JaredWyand  October","tariff","cars","Wisconsin","Detroit Economic Club","lever","Michigan","epic rant","long years","Fed","kids","course  Read","career politicians","Brexit states","politician     Republican","divorce","decades of broken promises","enemy","end","Ford Motor executives","Americans","revenge","choice","rednecks","shitty Obamacare bronze plan","Media","Win     Somebody","curtain","voting booth","wife","racists","music","bank","loyalty","rebuke","deal","decline","tidal wave","jobs","Balls","Speech","way","real vacation","things","clear head","pulse","popular vote","Democrat","elites","ability","Mexico","number","establishment","factories"],"id":"1017"}],"errors":[]}
# {"documents":[],"errors":[{"id":"1018","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["Jane Chastain s commentaries","Jane Chastain s alerts","interview Jane Chastain","free housing","free loans","politics  Jane","capitalism  Exclusive  Jane Chastain","free child care  free preschool","free health care  free food","free market system","nation s","free market capitalism","us free college","free lunch   Media","socialist road","people   s money      Don   t","country","lion   s share","training wage","minimum wage","isn   t","socialist system","didn   t","care of us","impact of Dems   living wage  proposal Published     mins","highest standard of living","government steps","poor economy","important fork","Election crossroads  Socialism","benevolent government","businesses","appeals","job creators","obvious fork","services","President Hillary","politician Hillary Clinton","job flipping hamburgers","years playing checkers","female TV sportscaster  spending    years","Social Security","economy collapses","socialist utopia","socialism communism slams","political commentator","Democrats","email BONUS","paid family","skills","watching television","British Prime Minister Margaret Thatcher","Medicare","gal","guy","Southern California based broadcaster  author","fact","hard work","Democratic colleagues","raising taxes","Republican colleagues","consumers","businessman Donald Trump","form of higher prices","hope","contact","economic ladder Americans","door","necessary goods","world","large outcry","pilot","special offers","WND","control","remainder","rungs","income necessary","present emphasis","problem","freedom","career politicians","ticket","JaneChastain com","Obamacare","news","means of production","sacrifice","jobs","parts","lives","major decisions","basic needs","private runway","different result","order","turn  hand","retirement center","power","personalities","fairness","faster rate","life","goals","responsibility","Wages","time","companies","Statistics","salary","belief"],"id":"1019"}],"errors":[]}
# {"documents":[{"keyPhrases":["Iran   s exports","Iran Turkey Border","Iran   s border","Turkey   s","exports of natural gas","problem   Iran","required gas","supplier of gas","Thursday night   Iran","mcm d   Iran","Iran   s Shana news agency","head of Gas Exports Measurement Facilities","border affairs of Iran   s Interior Ministry","current volume of natural gas","National Iranian Gas Company  NIGC","Tehran","Fri Oct               PM Energy Iran","country   s consumption","plan","day  mcm d   Officials","explosion","Monday   Akbarpour","hold","Majid Aqababaei","Turkish Botas company","Turkish territory","cubic meters","requited agreements","Europeans countries","readiness   Majid Bojarzadeh","director general","spokesman","Ankara","days   Sadeq Akbarpour","series of technicalities","domestic media","northwestern neighbor","Nabucco scheme","required coordination","month","possibility","piping","agenda","pipeline","supplies","Russia","Islamic Republic","Loading","result"],"id":"1020"}],"errors":[]}
# {"documents":[],"errors":[{"id":"1021","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["African Americans","Democratic Nation","manipulation","Racism Game","minorities","cover","majority     Divide","Intellectual Entitlement Mentality","implication   Voter ID Laws","Voting","DNC Policies","impediments","Election","Video"],"id":"1022"}],"errors":[]}
# {"documents":[],"errors":[{"id":"1023","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[],"errors":[{"id":"1024","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# {"documents":[{"keyPhrases":["day   Vitamin D","important benefits of vitamin D","Stop Depression Vitamin D","Michael Pollak Flickr    Vitamin D","body needs","body ward","form of sun block","diet","important vitamins","Alex Jones","soft bones","brittle bones","building healthy bones","shrimp  Milk  cereal  yogurt","signs of depression","sunny climate  spending    minutes","latest breaking news   specials","Getting    Minutes of Sunlight","pains","deficiency","children","general aches","salmon  sardines  egg yolk","orange juice","Infowars Crew","bone growth","developing stress fractures","disease  Studies","developing strong teeth","extra layers of clothing","colder climate  NEWSLETTER","taking supplements","winter months","multiple sclerosis  heart disease","calcium absorption","feeling","cases","allowance","effect","risk","women","low mood","genes","crucial role","Articles","dreaded flu","time","rest","protection","rays"],"id":"1025"}],"errors":[]}
# {"documents":[{"keyPhrases":["s News","Clinton   s war","NSA   s surveillance program","NSA  Binney","Hillary Clinton   s disregard of national security","Democratic National Committee   s server","disgruntled U S  intelligence worker  William Binney","NSA Whistleblower","matter","architect","hacked DNC emails","network log available","reports  analyses  breaking news","Daily Sheeple","personal email server","network logs","videos   Click","agenda","use","fable","voters","October","evidence","information","Putin","details","Russia","Wikileaks","FBI","hacks","talk radio","years","story","reluctance","agency","activity","pundits","database"],"id":"1026"}],"errors":[]}
# {"documents":[{"keyPhrases":["corrupt head","unethical behavior","clear conscience","Democratic National Committee","CNN"],"id":"1027"}],"errors":[]}
# {"documents":[{"keyPhrases":["corrupt political system","nation   s political system","Clintons    perfection of politics","private influence","Clintons    perfection of corruption","loyalists","incentives","dollars","dollar private foundation","usual money harvesting machine","Hillary Clinton","secrecy of private email servers","Clintons    harvester of corruption","big money contributors  conflicts of","speaking fees","Charles Hugh Smith  Let   s","inevitable result","doesn   t","nation  supporters","loot  vested interests","logical conclusion","commingling of public","vast flow of funds","contributions","ultimate product","November","schemes","Department of Justice","Dead","sense","possible maximization","federal government","conditions","critics","failing","eyes","parts"],"id":"1028"}],"errors":[]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# {"documents":[{"keyPhrases":["Tehran     AFP  Yusef Jalali Press TV  Tehran  Finland   s president","President of Finland Sauli Niinisto","Tehran Wed Oct               PM Iranian President Hassan Rouhani meeting","areas","cooperation","Iran  Finland sign   MoUs","energy  ICT","countries","visit","presidential palace","environment  Loading","documents","mutual ties"],"id":"1031"}],"errors":[]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 1 seconds." }
# {"documents":[{"keyPhrases":["NoDAPL Protectors","Best Ways","Senator","camp  Dallas Goldtooth","eop gov Jo Ellen Darcy  Assistant Secretary of Army Corp of Engineers joellen darcy us army mil","Sacred Stone Camp","Standing Rock Sioux Tribe   s fundraiser","President dmcos","Congressional Representative","Dakota Access  Denis McDonough  Chief of Staff","following list","Arlo Iron","September","permits","page","information"],"id":"1033"}],"errors":[]}
# {"documents":[],"errors":[{"id":"1034","message":"A document within the request was too large to be processed. Limit document size to: 10240 bytes"}]}
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 40 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 40 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 39 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 39 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 38 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 38 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 38 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 37 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 37 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 37 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 36 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 36 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 36 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 35 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 35 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 35 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 34 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 34 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 33 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 33 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 33 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 32 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 32 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 32 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 31 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 31 seconds." }
# { "statusCode": 429, "message": "Rate limit is exceeded. Try again in 31 seconds." }

# %%
{'documents': [{'text': "[ 'This is the biggest story not being reported.\\nWhile the world teeters on the brink of World War 3, the media is reporting on Kim Kardashian.\\nMeanwhile the Russians are deploying the new Satan-2 missile (designation given by NATO).\\nEach Satan-2 missile has the power to devastate an area the size of Texas.\\nhttp://www.nbcnews.com/news/wo... \\nhttp://www.dailymail.co.uk/sci...']", 'id': '1513'}]}

{'documents': ['{"id":"1513","text": "[ \'This is the biggest story not being reported.\\nWhile the world teeters on the brink of World War 3, the media is reporting on Kim Kardashian.\\nMeanwhile the Russians are deploying the new Satan-2 missile (designation given by NATO).\\nEach Satan-2 missile has the power to devastate an area the size of Texas.\\nhttp://www.nbcnews.com/news/wo... \\nhttp://www.dailymail.co.uk/sci...\']"}']}
