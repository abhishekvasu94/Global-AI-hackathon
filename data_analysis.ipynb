# %%
import pandas as pd
df = pd.read_csv('test_csv.csv')

# %% [markdown]
# # complete detection results dataset

# %%
df
# Out:
#      Unnamed: 0                                                url  score  \
# 0             0  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 1             1  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 2             2  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 3             3  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 4             4  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 5             5  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 6             6  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 7             7  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 8             8  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 9             9  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 10           10  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 11           11  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# ...

# %%
real_df = df.loc[df['score']==1]
real_df
# Out:
#      Unnamed: 0                                                url  score  \
# 502         502  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 503         503  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 504         504  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 505         505  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 506         506  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 507         507  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 508         508  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 509         509  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 510         510  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 511         511  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 512         512  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 513         513  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# ...

# %%
fake_df = df.loc[df['score']==0]
fake_df
# Out:
#      Unnamed: 0                                                url  score  \
# 0             0  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 1             1  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 2             2  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 3             3  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 4             4  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 5             5  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 6             6  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 7             7  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 8             8  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 9             9  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 10           10  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 11           11  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# ...

# %%
fake_df.loc[fake_df['fake']>0]
# Out:
#      Unnamed: 0                                                url  score  \
# 1             1  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 2             2  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 3             3  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 6             6  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 7             7  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 8             8  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 10           10  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 12           12  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 13           13  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 14           14  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 16           16  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 17           17  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# ...

# %% [markdown]
# # accuracy of fake detection

# %%
print(len(fake_df.loc[fake_df['fake']>0])/len(fake_df))
# Out:
# 0.8764940239043825

# %%
real_df.loc[real_df['real']>0]
# Out:
#      Unnamed: 0                                                url  score  \
# 502         502  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 503         503  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 506         506  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 507         507  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 508         508  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 509         509  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 510         510  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 512         512  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 514         514  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 515         515  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 516         516  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# 517         517  https://s3.amazonaws.com/clarifai-api/img2/pro...    1.0
# ...

# %% [markdown]
# # accuracy of real detection

# %%
print(len(real_df.loc[real_df['real']>0])/len(real_df))
# Out:
# 0.5691056910569106

# %%
graph_fake_df = fake_df.copy(deep=True)

# %%
graph_fake_df
# Out:
#      Unnamed: 0                                                url  score  \
# 0             0  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 1             1  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 2             2  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 3             3  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 4             4  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 5             5  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 6             6  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 7             7  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 8             8  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 9             9  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 10           10  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 11           11  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# ...

# %%
graph_fake_df[['fake']].fillna(value = 1-graph_fake_df[['real']],inplace=True)
# Out:
# C:\Users\Roshan Sridhar\Miniconda3\lib\site-packages\pandas\core\frame.py:2842: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
graph_fake_df
# Out:
#      Unnamed: 0                                                url  score  \
# 0             0  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 1             1  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 2             2  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 3             3  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 4             4  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 5             5  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 6             6  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 7             7  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 8             8  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 9             9  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 10           10  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 11           11  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# ...

# %%
graph_fake_df[['fake']] = graph_fake_df[['fake']].fillna(value = 1-graph_fake_df[['real']])

# %%
# Out:
#      Unnamed: 0                                                url  score  \
# 0             0  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 1             1  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 2             2  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 3             3  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 4             4  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 5             5  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 6             6  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 7             7  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 8             8  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 9             9  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 10           10  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# 11           11  https://s3.amazonaws.com/clarifai-api/img2/pro...    0.0
# ...

# %%
graph_fake_df.plot(y="fake",kind='hist')
import matplotlib.pyplot as plt
plt.show()
